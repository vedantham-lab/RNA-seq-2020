# %% [markdown]
# install.packages("ggVennDiagram")

# %% [markdown]
# install.packages("VennDiagram")

# %%
library(ggVennDiagram)
library(VennDiagram)
# Out:
# Warning message:
# “package ‘ggVennDiagram’ was built under R version 4.0.2”
# Warning message:
# “package ‘VennDiagram’ was built under R version 4.0.2”
# Loading required package: grid
#
# Loading required package: futile.logger
#
# Warning message:
# “package ‘futile.logger’ was built under R version 4.0.2”

# %%
setwd('/Users/marieshi/VV-3188_results2')

# %%
DEgenes = read.table("DEgenes_ensembl_merge.txt", fill = TRUE, header = TRUE)

# %%
head(DEgenes)
# Out:
#   Dev2019            VV
# 1 ENSMUSG00000018893 ENSMUSG00000000031
# 2 ENSMUSG00000035566 ENSMUSG00000000078
# 3 ENSMUSG00000000120 ENSMUSG00000000093
# 4 ENSMUSG00000050953 ENSMUSG00000000142
# 5 ENSMUSG00000025969 ENSMUSG00000000171
# 6 ENSMUSG00000090889 ENSMUSG00000000214

# %%
ggVennDiagram(DEgenes[1:2])
# Out:
# plot without title

# %%
png(file = "venn_diff.png")

# %%
venn.plot = draw.pairwise.venn(2580+530,1013+530,530,category = c("Dev2019","VV"), scaled=TRUE,  col = rep("black",
2), fill = c("BLUE","RED"))
# Out:
# plot without title

# %%
grid.draw(venn.plot)
# Out:
# plot without title

# %%
dev.off()
# Out:
# quartz_off_screen
#                 3

# %%
getwd()
# Out:
# [1] "/Users/marieshi/VV-3188_results2"
